# %%
from EnKF_func import *
from AuxFuncs import *
from DataGenerator import *

# %%
X,Y,Y_ = DataGen()

# %%
X,Y,Y_ = DataGen(STAGE=2,truestate=X)

# %%
EnKF(STAGE=2,truestate=X,trueobs=Y,PLOTTING=True,DEBUG=True)
# Out:
# ....................................................................................................1
# ....................................................................................................2
# ....................................................................................................3
# ....................................................................................................4
# ....................................................................................................5
# ....................................................................................................6
# ....................................................................................................7
# ....................................................................................................8
# ....................................................................................................9
# ...
